# %%
import collections
import math
import os
import random
import zipfile
import numpy as np
import urllib
import tensorflow as tf
# Out:
# C:\Users\MengnanChen\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
url='http://mattmahoney.net/dc/'

def maybe_download(filename,expected_bytes):
    if not os.path.exists(filename):
        filename,_=urllib.request.urlretrieve(url+filename,filename)
    statinfo=os.stat(filename)
    if statinfo.st_size==expected_bytes:
        print('File existed and verified ',filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify '+filename)
    return filename

filename=maybe_download('text8.zip',31344016)
# Out:
# File and verified  text8.zip

# %%
def read_data(filename):
    with zipfile.ZipFile(filename) as fin:
        data=tf.compat.as_str(fin.read(fin.namelist()[0])).split()
    return data

# %%
words=read_data(filename)
print('Data size',len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %%
len(set(words))
# Out:
# 253854

# %%
vocabulary_size=50000
def build_dataset(words):
    count=[['UNK',-1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    dictionary=dict()
    for word,_ in count:
        dictionary[word]=len(dictionary)
    data=list()
    unk_count=0
    for word in words:
        if word in dictionary:
            index=dictionary[word]
        else:
            index=0
            unk_count+=1
        data.append(index)  # 出现次数越高，序号越小，data为words每个词对应的序号
    count[0][1]=unk_count
    reverse_dictionary=dict(zip(dictionary.values(),dictionary.keys()))
    
    return data,count,dictionary,reverse_dictionary

# %%
x=[1,2,2,3,3,3]
collections.Counter(x).most_common(3)
# Out:
# [(3, 3), (2, 2), (1, 1)]

# %%
data,count,dictionary,reverse_dictionary=build_dataset(words)

# %%
data
# Out:
# [5234,
#  3081,
#  12,
#  6,
#  195,
#  2,
#  3134,
#  46,
#  59,
#  156,
#  128,
#  742,
#  477,
#  10572,
#  134,
#  1,
#  27350,
#  2,
#  1,
#  103,
#  855,
#  3,
#  1,
#  15068,
#  0,
#  2,
#  1,
#  151,
#  855,
#  3581,
#  1,
#  195,
#  11,
#  191,
#  59,
#  5,
#  6,
#  10713,
#  215,
#  7,
#  1325,
#  105,
#  455,
#  20,
#  59,
#  2732,
#  363,
#  7,
#  3673,
#  1,
#  709,
#  2,
#  372,
#  27,
#  41,
#  37,
#  54,
#  540,
#  98,
#  12,
#  6,
#  1424,
#  2758,
#  19,
#  568,
#  687,
#  7089,
#  1,
#  248,
#  5234,
#  11,
#  1053,
#  28,
#  1,
#  321,
#  249,
#  44612,
#  2878,
#  793,
#  187,
#  5234,
#  12,
#  6,
#  201,
#  603,
#  11,
#  1,
#  1135,
#  20,
#  2622,
#  26,
#  8984,
#  3,
#  280,
#  32,
#  4148,
#  142,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  154,
#  33,
#  363,
#  5234,
#  37,
#  1138,
#  7,
#  448,
#  345,
#  1819,
#  20,
#  4861,
#  1,
#  6754,
#  2,
#  7574,
#  1775,
#  567,
#  1,
#  94,
#  1,
#  248,
#  11065,
#  12,
#  52,
#  7089,
#  90,
#  27,
#  271,
#  38,
#  5949,
#  4862,
#  20300,
#  29,
#  0,
#  42,
#  318,
#  6,
#  25637,
#  528,
#  7574,
#  372,
#  5,
#  259,
#  2,
#  154,
#  26,
#  1207,
#  12,
#  7574,
#  201,
#  1577,
#  3,
#  15201,
#  333,
#  1775,
#  7089,
#  4861,
#  345,
#  765,
#  161,
#  407,
#  5691,
#  756,
#  2,
#  4106,
#  1132,
#  4332,
#  1537,
#  3,
#  568,
#  8118,
#  99,
#  5234,
#  11,
#  52,
#  1408,
#  687,
#  19,
#  154,
#  27,
#  11,
#  156,
#  7089,
#  37,
#  2034,
#  1424,
#  8175,
#  2,
#  154,
#  47,
#  694,
#  7,
#  32,
#  6,
#  4149,
#  247,
#  372,
#  77,
#  949,
#  79,
#  311,
#  31,
#  4779,
#  372,
#  508,
#  140,
#  2313,
#  3554,
#  365,
#  24,
#  1822,
#  7,
#  1903,
#  60,
#  11,
#  37,
#  8400,
#  79,
#  311,
#  6,
#  247,
#  372,
#  508,
#  32,
#  754,
#  79,
#  1733,
#  3,
#  8041,
#  24173,
#  3,
#  276,
#  1694,
#  20,
#  152,
#  1033,
#  96,
#  225,
#  372,
#  18,
#  1814,
#  25,
#  4779,
#  1557,
#  52,
#  8119,
#  1466,
#  24173,
#  3,
#  12744,
#  5,
#  6131,
#  20,
#  4188,
#  21149,
#  2428,
#  40,
#  16456,
#  3,
#  7240,
#  862,
#  2,
#  1194,
#  10208,
#  2515,
#  29,
#  15069,
#  188,
#  3,
#  49,
#  1124,
#  913,
#  7,
#  1050,
#  468,
#  12298,
#  7089,
#  134,
#  1,
#  1,
#  11065,
#  3056,
#  3,
#  12061,
#  735,
#  4779,
#  6599,
#  5,
#  14623,
#  28,
#  451,
#  486,
#  24173,
#  199,
#  296,
#  949,
#  5,
#  20028,
#  20301,
#  2,
#  0,
#  301,
#  7,
#  24173,
#  20301,
#  16457,
#  1,
#  30107,
#  2,
#  1,
#  94,
#  45,
#  3833,
#  3,
#  0,
#  3,
#  3808,
#  1,
#  3413,
#  2,
#  1,
#  1777,
#  188,
#  2,
#  1,
#  626,
#  1,
#  13142,
#  2,
#  4,
#  22,
#  91,
#  123,
#  285,
#  26,
#  244,
#  233,
#  7,
#  32,
#  437,
#  26185,
#  2,
#  174,
#  5234,
#  7700,
#  2535,
#  5,
#  30,
#  96,
#  2,
#  290,
#  603,
#  4309,
#  20,
#  1,
#  13142,
#  16457,
#  50,
#  188,
#  118,
#  47,
#  360,
#  20,
#  1,
#  385,
#  243,
#  97,
#  32,
#  5235,
#  35,
#  332,
#  2724,
#  19,
#  1,
#  839,
#  1377,
#  28,
#  33,
#  8762,
#  47,
#  6471,
#  35,
#  3244,
#  1,
#  27350,
#  29,
#  552,
#  42433,
#  40,
#  31,
#  128,
#  0,
#  436,
#  85,
#  1,
#  65,
#  2,
#  1,
#  103,
#  463,
#  84,
#  3,
#  26,
#  233,
#  19,
#  48,
#  12,
#  26185,
#  2,
#  174,
#  5234,
#  5,
#  1,
#  174,
#  840,
#  1,
#  46,
#  7,
#  90,
#  1,
#  195,
#  7,
#  1015,
#  1044,
#  43,
#  70,
#  4862,
#  18,
#  937,
#  14921,
#  4572,
#  165,
#  0,
#  5,
#  30,
#  40562,
#  11816,
#  22893,
#  260,
#  1226,
#  0,
#  0,
#  4,
#  23,
#  8,
#  17,
#  100,
#  36,
#  629,
#  1,
#  2663,
#  64,
#  372,
#  34,
#  49,
#  76,
#  94,
#  688,
#  14778,
#  4045,
#  29,
#  818,
#  918,
#  12,
#  102,
#  5,
#  11065,
#  2535,
#  363,
#  6,
#  6055,
#  3,
#  663,
#  5,
#  1,
#  64,
#  702,
#  436,
#  41,
#  4219,
#  1290,
#  20,
#  36,
#  11,
#  31,
#  4779,
#  3,
#  95,
#  26,
#  50,
#  30,
#  5213,
#  5,
#  4,
#  23,
#  9,
#  17,
#  5,
#  1,
#  5349,
#  2,
#  1,
#  151,
#  855,
#  468,
#  12298,
#  335,
#  31,
#  17195,
#  2435,
#  201,
#  1294,
#  142,
#  12298,
#  216,
#  38,
#  90,
#  1,
#  248,
#  5234,
#  56,
#  117,
#  7089,
#  39,
#  1207,
#  33,
#  198,
#  12,
#  1,
#  46,
#  182,
#  4779,
#  530,
#  3,
#  12298,
#  12,
#  1,
#  1835,
#  2,
#  1913,
#  5234,
#  42,
#  35,
#  33,
#  229,
#  76,
#  4779,
#  436,
#  734,
#  2400,
#  3,
#  1,
#  195,
#  0,
#  18,
#  87,
#  1074,
#  12,
#  31,
#  14023,
#  30108,
#  19,
#  1,
#  12062,
#  0,
#  35,
#  51,
#  2420,
#  617,
#  5,
#  1,
#  151,
#  855,
#  1,
#  46,
#  568,
#  8717,
#  4779,
#  2936,
#  1034,
#  14498,
#  27,
#  11,
#  637,
#  360,
#  20,
#  27,
#  5386,
#  155,
#  192,
#  2936,
#  1034,
#  14498,
#  335,
#  154,
#  11,
#  918,
#  5,
#  4,
#  13,
#  21,
#  8,
#  20,
#  1,
#  195,
#  4779,
#  18,
#  990,
#  12,
#  6,
#  568,
#  1607,
#  27,
#  11,
#  14,
#  33,
#  891,
#  20,
#  48,
#  849,
#  14498,
#  12,
#  1,
#  1835,
#  2,
#  174,
#  4779,
#  209,
#  5,
#  154,
#  11,
#  918,
#  14498,
#  5464,
#  24,
#  1,
#  420,
#  12954,
#  918,
#  11,
#  6879,
#  5,
#  33,
#  140,
#  36,
#  1347,
#  1,
#  2879,
#  2,
#  15069,
#  918,
#  0,
#  155,
#  100,
#  3466,
#  39,
#  653,
#  446,
#  7,
#  90,
#  3,
#  3134,
#  44,
#  918,
#  12,
#  47,
#  3592,
#  55,
#  12,
#  15348,
#  1556,
#  14,
#  2966,
#  5,
#  45,
#  259,
#  14498,
#  1165,
#  154,
#  36,
#  89,
#  3222,
#  1132,
#  53,
#  39,
#  752,
#  446,
#  7,
#  90,
#  1050,
#  523,
#  3,
#  1792,
#  5,
#  5806,
#  24,
#  1557,
#  2,
#  5129,
#  3,
#  1294,
#  14498,
#  15,
#  2655,
#  2,
#  11065,
#  34,
#  36,
#  89,
#  29373,
#  0,
#  967,
#  31,
#  1335,
#  519,
#  100,
#  1132,
#  3,
#  309,
#  160,
#  513,
#  1,
#  806,
#  2,
#  44,
#  1259,
#  219,
#  1259,
#  1038,
#  34,
#  1392,
#  1,
#  909,
#  2,
#  742,
#  65,
#  967,
#  5,
#  443,
#  33,
#  74,
#  2914,
#  20,
#  76,
#  4,
#  74,
#  2966,
#  28,
#  1,
#  1259,
#  2,
#  276,
#  1556,
#  160,
#  4320,
#  2519,
#  499,
#  5,
#  728,
#  10639,
#  18742,
#  31,
#  763,
#  247,
#  987,
#  74,
#  32,
#  178,
#  98,
#  7,
#  741,
#  3273,
#  24,
#  913,
#  7,
#  1,
#  363,
#  2,
#  443,
#  14498,
#  15,
#  949,
#  40,
#  2026,
#  223,
#  151,
#  742,
#  477,
#  1819,
#  3,
#  30,
#  2986,
#  40,
#  1022,
#  5,
#  1,
#  855,
#  2,
#  4,
#  13,
#  21,
#  13,
#  5,
#  303,
#  14498,
#  15,
#  603,
#  2,
#  918,
#  11,
#  648,
#  27,
#  18,
#  348,
#  5,
#  6,
#  113,
#  2,
#  312,
#  80,
#  30,
#  3568,
#  3,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  48,
#  2,
#  30,
#  949,
#  14,
#  51,
#  2159,
#  1590,
#  68,
#  622,
#  2750,
#  26186,
#  15,
#  15644,
#  5,
#  30,
#  1,
#  10465,
#  3,
#  45,
#  200,
#  26186,
#  1461,
#  20,
#  52,
#  637,
#  1046,
#  345,
#  1775,
#  134,
#  1,
#  2582,
#  2,
#  94,
#  918,
#  12,
#  6,
#  245,
#  390,
#  446,
#  5,
#  153,
#  3,
#  1,
#  148,
#  2582,
#  2,
#  372,
#  40,
#  4580,
#  20848,
#  29,
#  9217,
#  5,
#  1,
#  941,
#  1975,
#  2,
#  372,
#  20,
#  1,
#  1132,
#  26,
#  45,
#  1729,
#  36,
#  5214,
#  15644,
#  3,
#  6,
#  144,
#  2,
#  0,
#  5,
#  34,
#  1132,
#  74,
#  9712,
#  5,
#  5826,
#  2,
#  0,
#  67,
#  62,
#  27,
#  18,
#  5,
#  44,
#  568,
#  763,
#  7,
#  176,
#  95,
#  14,
#  119,
#  918,
#  685,
#  1146,
#  79,
#  124,
#  508,
#  13043,
#  5568,
#  311,
#  7,
#  370,
#  7,
#  4107,
#  1,
#  1798,
#  7,
#  119,
#  5465,
#  918,
#  3,
#  154,
#  72,
#  39,
#  5,
#  609,
#  184,
#  20,
#  11,
#  609,
#  200,
#  95,
#  185,
#  12,
#  72,
#  6188,
#  9034,
#  12,
#  7184,
#  72,
#  1226,
#  1,
#  33801,
#  2,
#  1,
#  1798,
#  26186,
#  364,
#  89,
#  392,
#  31,
#  4779,
#  36,
#  1046,
#  67,
#  1,
#  2758,
#  42434,
#  2069,
#  30,
#  949,
#  40,
#  2026,
#  25,
#  56,
#  0,
#  9930,
#  7089,
#  142,
#  4187,
#  2,
#  30,
#  502,
#  26,
#  3236,
#  ...]

# %%
dictionary
# Out:
# {'UNK': 0,
#  'the': 1,
#  'of': 2,
#  'and': 3,
#  'one': 4,
#  'in': 5,
#  'a': 6,
#  'to': 7,
#  'zero': 8,
#  'nine': 9,
#  'two': 10,
#  'is': 11,
#  'as': 12,
#  'eight': 13,
#  'for': 14,
#  's': 15,
#  'five': 16,
#  'three': 17,
#  'was': 18,
#  'by': 19,
#  'that': 20,
#  'four': 21,
#  'six': 22,
#  'seven': 23,
#  'with': 24,
#  'on': 25,
#  'are': 26,
#  'it': 27,
#  'from': 28,
#  'or': 29,
#  'his': 30,
#  'an': 31,
#  'be': 32,
#  'this': 33,
#  'which': 34,
#  'at': 35,
#  'he': 36,
#  'also': 37,
#  'not': 38,
#  'have': 39,
#  'were': 40,
#  'has': 41,
#  'but': 42,
#  'other': 43,
#  'their': 44,
#  'its': 45,
#  'first': 46,
#  'they': 47,
#  'some': 48,
#  'had': 49,
#  'all': 50,
#  'more': 51,
#  'most': 52,
#  'can': 53,
#  'been': 54,
#  'such': 55,
#  'many': 56,
#  'who': 57,
#  'new': 58,
#  'used': 59,
#  'there': 60,
#  'after': 61,
#  'when': 62,
#  'into': 63,
#  'american': 64,
#  'time': 65,
#  'these': 66,
#  'only': 67,
#  'see': 68,
#  'may': 69,
#  'than': 70,
#  'world': 71,
#  'i': 72,
#  'b': 73,
#  'would': 74,
#  'd': 75,
#  'no': 76,
#  'however': 77,
#  'between': 78,
#  'about': 79,
#  'over': 80,
#  'years': 81,
#  'states': 82,
#  'people': 83,
#  'war': 84,
#  'during': 85,
#  'united': 86,
#  'known': 87,
#  'if': 88,
#  'called': 89,
#  'use': 90,
#  'th': 91,
#  'system': 92,
#  'often': 93,
#  'state': 94,
#  'so': 95,
#  'history': 96,
#  'will': 97,
#  'up': 98,
#  'while': 99,
#  'where': 100,
#  'city': 101,
#  'being': 102,
#  'english': 103,
#  'then': 104,
#  'any': 105,
#  'both': 106,
#  'under': 107,
#  'out': 108,
#  'made': 109,
#  'well': 110,
#  'her': 111,
#  'e': 112,
#  'number': 113,
#  'government': 114,
#  'them': 115,
#  'm': 116,
#  'later': 117,
#  'since': 118,
#  'him': 119,
#  'part': 120,
#  'name': 121,
#  'c': 122,
#  'century': 123,
#  'through': 124,
#  'because': 125,
#  'x': 126,
#  'university': 127,
#  'early': 128,
#  'life': 129,
#  'british': 130,
#  'year': 131,
#  'like': 132,
#  'same': 133,
#  'including': 134,
#  'became': 135,
#  'example': 136,
#  'day': 137,
#  'each': 138,
#  'even': 139,
#  'work': 140,
#  'language': 141,
#  'although': 142,
#  'several': 143,
#  'form': 144,
#  'john': 145,
#  'u': 146,
#  'national': 147,
#  'very': 148,
#  'much': 149,
#  'g': 150,
#  'french': 151,
#  'before': 152,
#  'general': 153,
#  'what': 154,
#  't': 155,
#  'against': 156,
#  'n': 157,
#  'high': 158,
#  'links': 159,
#  'could': 160,
#  'based': 161,
#  'those': 162,
#  'now': 163,
#  'second': 164,
#  'de': 165,
#  'music': 166,
#  'another': 167,
#  'large': 168,
#  'she': 169,
#  'f': 170,
#  'external': 171,
#  'german': 172,
#  'different': 173,
#  'modern': 174,
#  'great': 175,
#  'do': 176,
#  'common': 177,
#  'set': 178,
#  'list': 179,
#  'south': 180,
#  'series': 181,
#  'major': 182,
#  'game': 183,
#  'power': 184,
#  'long': 185,
#  'country': 186,
#  'king': 187,
#  'law': 188,
#  'group': 189,
#  'film': 190,
#  'still': 191,
#  'until': 192,
#  'north': 193,
#  'international': 194,
#  'term': 195,
#  'we': 196,
#  'end': 197,
#  'book': 198,
#  'found': 199,
#  'own': 200,
#  'political': 201,
#  'party': 202,
#  'order': 203,
#  'usually': 204,
#  'president': 205,
#  'church': 206,
#  'you': 207,
#  'death': 208,
#  'theory': 209,
#  'area': 210,
#  'around': 211,
#  'include': 212,
#  'god': 213,
#  'ii': 214,
#  'way': 215,
#  'did': 216,
#  'military': 217,
#  'population': 218,
#  'using': 219,
#  'though': 220,
#  'small': 221,
#  'following': 222,
#  'within': 223,
#  'non': 224,
#  'human': 225,
#  'left': 226,
#  'main': 227,
#  'among': 228,
#  'point': 229,
#  'r': 230,
#  'due': 231,
#  'p': 232,
#  'considered': 233,
#  'public': 234,
#  'popular': 235,
#  'computer': 236,
#  'west': 237,
#  'family': 238,
#  'east': 239,
#  'information': 240,
#  'important': 241,
#  'european': 242,
#  'man': 243,
#  'sometimes': 244,
#  'right': 245,
#  'old': 246,
#  'free': 247,
#  'word': 248,
#  'without': 249,
#  'last': 250,
#  'us': 251,
#  'members': 252,
#  'given': 253,
#  'times': 254,
#  'roman': 255,
#  'make': 256,
#  'h': 257,
#  'age': 258,
#  'place': 259,
#  'l': 260,
#  'thus': 261,
#  'science': 262,
#  'case': 263,
#  'become': 264,
#  'systems': 265,
#  'union': 266,
#  'born': 267,
#  'york': 268,
#  'line': 269,
#  'countries': 270,
#  'does': 271,
#  'isbn': 272,
#  'st': 273,
#  'control': 274,
#  'various': 275,
#  'others': 276,
#  'house': 277,
#  'article': 278,
#  'island': 279,
#  'should': 280,
#  'led': 281,
#  'back': 282,
#  'period': 283,
#  'player': 284,
#  'europe': 285,
#  'languages': 286,
#  'central': 287,
#  'water': 288,
#  'few': 289,
#  'western': 290,
#  'home': 291,
#  'began': 292,
#  'generally': 293,
#  'less': 294,
#  'k': 295,
#  'similar': 296,
#  'written': 297,
#  'original': 298,
#  'best': 299,
#  'must': 300,
#  'according': 301,
#  'school': 302,
#  'france': 303,
#  'air': 304,
#  'single': 305,
#  'force': 306,
#  'v': 307,
#  'land': 308,
#  'groups': 309,
#  'down': 310,
#  'how': 311,
#  'works': 312,
#  'development': 313,
#  'official': 314,
#  'support': 315,
#  'england': 316,
#  'j': 317,
#  'rather': 318,
#  'data': 319,
#  'space': 320,
#  'greek': 321,
#  'km': 322,
#  'named': 323,
#  'germany': 324,
#  'just': 325,
#  'games': 326,
#  'said': 327,
#  'version': 328,
#  'late': 329,
#  'earth': 330,
#  'company': 331,
#  'every': 332,
#  'economic': 333,
#  'short': 334,
#  'published': 335,
#  'black': 336,
#  'army': 337,
#  'off': 338,
#  'london': 339,
#  'million': 340,
#  'body': 341,
#  'field': 342,
#  'christian': 343,
#  'either': 344,
#  'social': 345,
#  'empire': 346,
#  'o': 347,
#  'developed': 348,
#  'standard': 349,
#  'court': 350,
#  'service': 351,
#  'kingdom': 352,
#  'along': 353,
#  'college': 354,
#  'republic': 355,
#  'sea': 356,
#  'america': 357,
#  'today': 358,
#  'result': 359,
#  'held': 360,
#  'team': 361,
#  'light': 362,
#  'means': 363,
#  'never': 364,
#  'especially': 365,
#  'third': 366,
#  'further': 367,
#  'character': 368,
#  'forces': 369,
#  'take': 370,
#  'men': 371,
#  'society': 372,
#  'show': 373,
#  'open': 374,
#  'possible': 375,
#  'fact': 376,
#  'battle': 377,
#  'took': 378,
#  'former': 379,
#  'books': 380,
#  'soviet': 381,
#  'river': 382,
#  'children': 383,
#  'having': 384,
#  'good': 385,
#  'local': 386,
#  'current': 387,
#  'son': 388,
#  'process': 389,
#  'natural': 390,
#  'present': 391,
#  'himself': 392,
#  'islands': 393,
#  'total': 394,
#  'near': 395,
#  'white': 396,
#  'days': 397,
#  'person': 398,
#  'itself': 399,
#  'seen': 400,
#  'culture': 401,
#  'little': 402,
#  'above': 403,
#  'software': 404,
#  'largest': 405,
#  'words': 406,
#  'upon': 407,
#  'level': 408,
#  'father': 409,
#  'created': 410,
#  'side': 411,
#  'red': 412,
#  'references': 413,
#  'press': 414,
#  'full': 415,
#  'region': 416,
#  'almost': 417,
#  'image': 418,
#  'al': 419,
#  'famous': 420,
#  'play': 421,
#  'came': 422,
#  'role': 423,
#  'once': 424,
#  'certain': 425,
#  'league': 426,
#  'jewish': 427,
#  'james': 428,
#  'january': 429,
#  'site': 430,
#  'again': 431,
#  'numbers': 432,
#  'art': 433,
#  'member': 434,
#  'areas': 435,
#  'movement': 436,
#  'religious': 437,
#  'type': 438,
#  'march': 439,
#  'community': 440,
#  'story': 441,
#  'played': 442,
#  'production': 443,
#  'released': 444,
#  'center': 445,
#  'rights': 446,
#  'real': 447,
#  'related': 448,
#  'foreign': 449,
#  'low': 450,
#  'ancient': 451,
#  'terms': 452,
#  'view': 453,
#  'source': 454,
#  'act': 455,
#  'minister': 456,
#  'change': 457,
#  'energy': 458,
#  'produced': 459,
#  'research': 460,
#  'actor': 461,
#  'making': 462,
#  'civil': 463,
#  'december': 464,
#  'women': 465,
#  'special': 466,
#  'style': 467,
#  'william': 468,
#  'design': 469,
#  'japanese': 470,
#  'available': 471,
#  'chinese': 472,
#  'forms': 473,
#  'canada': 474,
#  'northern': 475,
#  'died': 476,
#  'class': 477,
#  'living': 478,
#  'next': 479,
#  'particular': 480,
#  'program': 481,
#  'council': 482,
#  'television': 483,
#  'head': 484,
#  'david': 485,
#  'china': 486,
#  'middle': 487,
#  'established': 488,
#  'hand': 489,
#  'bc': 490,
#  'far': 491,
#  'july': 492,
#  'function': 493,
#  'position': 494,
#  'y': 495,
#  'built': 496,
#  'george': 497,
#  'band': 498,
#  'together': 499,
#  'w': 500,
#  'latin': 501,
#  'thought': 502,
#  'eastern': 503,
#  'charles': 504,
#  'parts': 505,
#  'instead': 506,
#  'study': 507,
#  'might': 508,
#  'india': 509,
#  'code': 510,
#  'included': 511,
#  'meaning': 512,
#  'trade': 513,
#  'per': 514,
#  'june': 515,
#  'least': 516,
#  'half': 517,
#  'model': 518,
#  'economy': 519,
#  'prime': 520,
#  'traditional': 521,
#  'always': 522,
#  'capital': 523,
#  'range': 524,
#  'november': 525,
#  'emperor': 526,
#  'young': 527,
#  'anti': 528,
#  'final': 529,
#  'text': 530,
#  'players': 531,
#  'uk': 532,
#  'april': 533,
#  'run': 534,
#  'september': 535,
#  'addition': 536,
#  'radio': 537,
#  'live': 538,
#  'august': 539,
#  'taken': 540,
#  'note': 541,
#  'italian': 542,
#  'lost': 543,
#  'nature': 544,
#  'project': 545,
#  'technology': 546,
#  'spanish': 547,
#  'october': 548,
#  'recent': 549,
#  'rate': 550,
#  'won': 551,
#  'true': 552,
#  'value': 553,
#  'uses': 554,
#  'russian': 555,
#  'est': 556,
#  'wrote': 557,
#  'effect': 558,
#  'album': 559,
#  'southern': 560,
#  'africa': 561,
#  'whose': 562,
#  'top': 563,
#  'historical': 564,
#  'australia': 565,
#  'catholic': 566,
#  'particularly': 567,
#  'self': 568,
#  'structure': 569,
#  'record': 570,
#  'evidence': 571,
#  'rule': 572,
#  'themselves': 573,
#  'influence': 574,
#  'cases': 575,
#  'subject': 576,
#  'referred': 577,
#  'continued': 578,
#  'nations': 579,
#  'below': 580,
#  'rock': 581,
#  'japan': 582,
#  'com': 583,
#  'song': 584,
#  'throughout': 585,
#  'names': 586,
#  'female': 587,
#  'title': 588,
#  'therefore': 589,
#  'our': 590,
#  'office': 591,
#  'star': 592,
#  'paul': 593,
#  'too': 594,
#  'cities': 595,
#  'february': 596,
#  'independent': 597,
#  'author': 598,
#  'problem': 599,
#  'species': 600,
#  'education': 601,
#  'done': 602,
#  'philosophy': 603,
#  'come': 604,
#  'higher': 605,
#  'originally': 606,
#  'market': 607,
#  'town': 608,
#  'my': 609,
#  'season': 610,
#  'love': 611,
#  'strong': 612,
#  'israel': 613,
#  'irish': 614,
#  'writer': 615,
#  'films': 616,
#  'elements': 617,
#  'robert': 618,
#  'whether': 619,
#  'despite': 620,
#  'eventually': 621,
#  'here': 622,
#  'football': 623,
#  'action': 624,
#  'internet': 625,
#  'individual': 626,
#  'sound': 627,
#  'network': 628,
#  'described': 629,
#  'practice': 630,
#  'characters': 631,
#  're': 632,
#  'royal': 633,
#  'la': 634,
#  'events': 635,
#  'formed': 636,
#  'commonly': 637,
#  'base': 638,
#  'received': 639,
#  'african': 640,
#  'problems': 641,
#  'food': 642,
#  'jews': 643,
#  'able': 644,
#  'male': 645,
#  'typically': 646,
#  'mass': 647,
#  'complex': 648,
#  'lower': 649,
#  'includes': 650,
#  'outside': 651,
#  'legal': 652,
#  'complete': 653,
#  'significant': 654,
#  'parliament': 655,
#  'actually': 656,
#  'business': 657,
#  'fiction': 658,
#  'physical': 659,
#  'followed': 660,
#  'deaths': 661,
#  'key': 662,
#  'leader': 663,
#  'widely': 664,
#  'page': 665,
#  'basic': 666,
#  'types': 667,
#  'henry': 668,
#  'elected': 669,
#  'beginning': 670,
#  'fire': 671,
#  'building': 672,
#  'independence': 673,
#  'went': 674,
#  'movie': 675,
#  'aircraft': 676,
#  'ever': 677,
#  'canadian': 678,
#  'material': 679,
#  'births': 680,
#  'video': 681,
#  'news': 682,
#  'future': 683,
#  'scientific': 684,
#  'simply': 685,
#  'go': 686,
#  'defined': 687,
#  'laws': 688,
#  'get': 689,
#  'close': 690,
#  'industry': 691,
#  'specific': 692,
#  'examples': 693,
#  'believe': 694,
#  'services': 695,
#  'idea': 696,
#  'method': 697,
#  'introduced': 698,
#  'points': 699,
#  'return': 700,
#  'cause': 701,
#  'indian': 702,
#  'britain': 703,
#  'features': 704,
#  'majority': 705,
#  'size': 706,
#  'post': 707,
#  'lead': 708,
#  'organization': 709,
#  'cannot': 710,
#  'designed': 711,
#  'ireland': 712,
#  'cross': 713,
#  'classical': 714,
#  'personal': 715,
#  'writing': 716,
#  'concept': 717,
#  'associated': 718,
#  'required': 719,
#  'soon': 720,
#  'changes': 721,
#  'california': 722,
#  'located': 723,
#  'sense': 724,
#  'believed': 725,
#  'away': 726,
#  'started': 727,
#  'co': 728,
#  'religion': 729,
#  'mother': 730,
#  'county': 731,
#  'rules': 732,
#  'studies': 733,
#  'yet': 734,
#  'find': 735,
#  'knowledge': 736,
#  'put': 737,
#  'founded': 738,
#  'policy': 739,
#  'currently': 740,
#  'provide': 741,
#  'working': 742,
#  'media': 743,
#  'election': 744,
#  'australian': 745,
#  'me': 746,
#  'thomas': 747,
#  'allowed': 748,
#  'russia': 749,
#  'earlier': 750,
#  'greater': 751,
#  'limited': 752,
#  'object': 753,
#  'brought': 754,
#  'online': 755,
#  'association': 756,
#  'lord': 757,
#  'mostly': 758,
#  'blue': 759,
#  'constitution': 760,
#  'across': 761,
#  'added': 762,
#  'interest': 763,
#  'things': 764,
#  'relations': 765,
#  'speed': 766,
#  'federal': 767,
#  'singer': 768,
#  'effects': 769,
#  'growth': 770,
#  'sources': 771,
#  'your': 772,
#  'remains': 773,
#  'z': 774,
#  'probably': 775,
#  'gave': 776,
#  'simple': 777,
#  'attack': 778,
#  'longer': 779,
#  'reference': 780,
#  'saint': 781,
#  'success': 782,
#  'killed': 783,
#  'past': 784,
#  'career': 785,
#  'need': 786,
#  'park': 787,
#  'definition': 788,
#  'say': 789,
#  'etc': 790,
#  'give': 791,
#  'peace': 792,
#  'chief': 793,
#  'stories': 794,
#  'security': 795,
#  'wide': 796,
#  'ball': 797,
#  'saw': 798,
#  'machine': 799,
#  'better': 800,
#  'cell': 801,
#  'leading': 802,
#  'becomes': 803,
#  'spain': 804,
#  'larger': 805,
#  'products': 806,
#  'parties': 807,
#  'night': 808,
#  'remained': 809,
#  'prize': 810,
#  'months': 811,
#  'website': 812,
#  'big': 813,
#  'cultural': 814,
#  'money': 815,
#  'help': 816,
#  'territory': 817,
#  'private': 818,
#  'moved': 819,
#  'letter': 820,
#  'wife': 821,
#  'politics': 822,
#  'lines': 823,
#  'largely': 824,
#  'contains': 825,
#  'companies': 826,
#  'lake': 827,
#  'perhaps': 828,
#  'green': 829,
#  'already': 830,
#  'dead': 831,
#  'iii': 832,
#  'library': 833,
#  'separate': 834,
#  'refer': 835,
#  'makes': 836,
#  'appeared': 837,
#  'dutch': 838,
#  'holy': 839,
#  'era': 840,
#  'novel': 841,
#  'successful': 842,
#  'italy': 843,
#  'letters': 844,
#  'results': 845,
#  'matter': 846,
#  'produce': 847,
#  'origin': 848,
#  'claim': 849,
#  'whole': 850,
#  'directly': 851,
#  'attempt': 852,
#  'actress': 853,
#  'surface': 854,
#  'revolution': 855,
#  'highly': 856,
#  'caused': 857,
#  'status': 858,
#  'musical': 859,
#  'richard': 860,
#  'commercial': 861,
#  'division': 862,
#  'color': 863,
#  'health': 864,
#  'coast': 865,
#  'release': 866,
#  'latter': 867,
#  'authority': 868,
#  'treaty': 869,
#  'turn': 870,
#  'michael': 871,
#  'nation': 872,
#  'direct': 873,
#  'asia': 874,
#  'edition': 875,
#  'programming': 876,
#  'playing': 877,
#  'date': 878,
#  'mary': 879,
#  'native': 880,
#  'whom': 881,
#  'married': 882,
#  'towards': 883,
#  'issues': 884,
#  'double': 885,
#  'primary': 886,
#  'basis': 887,
#  'allow': 888,
#  'enough': 889,
#  'memory': 890,
#  'reason': 891,
#  'web': 892,
#  'exist': 893,
#  'provided': 894,
#  'oil': 895,
#  'course': 896,
#  'functions': 897,
#  'alexander': 898,
#  'analysis': 899,
#  'chemical': 900,
#  'mid': 901,
#  'replaced': 902,
#  'queen': 903,
#  'claims': 904,
#  'tv': 905,
#  'sun': 906,
#  'literature': 907,
#  'metal': 908,
#  'amount': 909,
#  'divided': 910,
#  'blood': 911,
#  'likely': 912,
#  'access': 913,
#  'average': 914,
#  'length': 915,
#  'smaller': 916,
#  'medical': 917,
#  'property': 918,
#  'students': 919,
#  'degree': 920,
#  'elections': 921,
#  'club': 922,
#  'claimed': 923,
#  'performance': 924,
#  'director': 925,
#  'digital': 926,
#  'front': 927,
#  'museum': 928,
#  'difficult': 929,
#  'tradition': 930,
#  'nearly': 931,
#  'schools': 932,
#  'washington': 933,
#  'gas': 934,
#  'jesus': 935,
#  'map': 936,
#  'louis': 937,
#  'rome': 938,
#  'unit': 939,
#  'baseball': 940,
#  'mind': 941,
#  'peter': 942,
#  'mark': 943,
#  'collection': 944,
#  'product': 945,
#  'congress': 946,
#  'programs': 947,
#  'changed': 948,
#  'ideas': 949,
#  'moon': 950,
#  'entire': 951,
#  'user': 952,
#  'ground': 953,
#  'records': 954,
#  'frequently': 955,
#  'increase': 956,
#  'highest': 957,
#  'sent': 958,
#  'finally': 959,
#  'board': 960,
#  'don': 961,
#  'notable': 962,
#  'read': 963,
#  'methods': 964,
#  'recently': 965,
#  'bit': 966,
#  'involved': 967,
#  'variety': 968,
#  'call': 969,
#  'democratic': 970,
#  'ten': 971,
#  'served': 972,
#  'minor': 973,
#  'hard': 974,
#  'birth': 975,
#  'objects': 976,
#  'nuclear': 977,
#  'increased': 978,
#  'section': 979,
#  'street': 980,
#  'windows': 981,
#  'relatively': 982,
#  'car': 983,
#  'move': 984,
#  'create': 985,
#  'returned': 986,
#  'bank': 987,
#  'conditions': 988,
#  'operation': 989,
#  'adopted': 990,
#  'relationship': 991,
#  'christ': 992,
#  'hall': 993,
#  'appear': 994,
#  'rest': 995,
#  'child': 996,
#  'element': 997,
#  'appears': 998,
#  'takes': 999,
#  ...}

# %%
reverse_dictionary
# Out:
# {0: 'UNK',
#  1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'one',
#  5: 'in',
#  6: 'a',
#  7: 'to',
#  8: 'zero',
#  9: 'nine',
#  10: 'two',
#  11: 'is',
#  12: 'as',
#  13: 'eight',
#  14: 'for',
#  15: 's',
#  16: 'five',
#  17: 'three',
#  18: 'was',
#  19: 'by',
#  20: 'that',
#  21: 'four',
#  22: 'six',
#  23: 'seven',
#  24: 'with',
#  25: 'on',
#  26: 'are',
#  27: 'it',
#  28: 'from',
#  29: 'or',
#  30: 'his',
#  31: 'an',
#  32: 'be',
#  33: 'this',
#  34: 'which',
#  35: 'at',
#  36: 'he',
#  37: 'also',
#  38: 'not',
#  39: 'have',
#  40: 'were',
#  41: 'has',
#  42: 'but',
#  43: 'other',
#  44: 'their',
#  45: 'its',
#  46: 'first',
#  47: 'they',
#  48: 'some',
#  49: 'had',
#  50: 'all',
#  51: 'more',
#  52: 'most',
#  53: 'can',
#  54: 'been',
#  55: 'such',
#  56: 'many',
#  57: 'who',
#  58: 'new',
#  59: 'used',
#  60: 'there',
#  61: 'after',
#  62: 'when',
#  63: 'into',
#  64: 'american',
#  65: 'time',
#  66: 'these',
#  67: 'only',
#  68: 'see',
#  69: 'may',
#  70: 'than',
#  71: 'world',
#  72: 'i',
#  73: 'b',
#  74: 'would',
#  75: 'd',
#  76: 'no',
#  77: 'however',
#  78: 'between',
#  79: 'about',
#  80: 'over',
#  81: 'years',
#  82: 'states',
#  83: 'people',
#  84: 'war',
#  85: 'during',
#  86: 'united',
#  87: 'known',
#  88: 'if',
#  89: 'called',
#  90: 'use',
#  91: 'th',
#  92: 'system',
#  93: 'often',
#  94: 'state',
#  95: 'so',
#  96: 'history',
#  97: 'will',
#  98: 'up',
#  99: 'while',
#  100: 'where',
#  101: 'city',
#  102: 'being',
#  103: 'english',
#  104: 'then',
#  105: 'any',
#  106: 'both',
#  107: 'under',
#  108: 'out',
#  109: 'made',
#  110: 'well',
#  111: 'her',
#  112: 'e',
#  113: 'number',
#  114: 'government',
#  115: 'them',
#  116: 'm',
#  117: 'later',
#  118: 'since',
#  119: 'him',
#  120: 'part',
#  121: 'name',
#  122: 'c',
#  123: 'century',
#  124: 'through',
#  125: 'because',
#  126: 'x',
#  127: 'university',
#  128: 'early',
#  129: 'life',
#  130: 'british',
#  131: 'year',
#  132: 'like',
#  133: 'same',
#  134: 'including',
#  135: 'became',
#  136: 'example',
#  137: 'day',
#  138: 'each',
#  139: 'even',
#  140: 'work',
#  141: 'language',
#  142: 'although',
#  143: 'several',
#  144: 'form',
#  145: 'john',
#  146: 'u',
#  147: 'national',
#  148: 'very',
#  149: 'much',
#  150: 'g',
#  151: 'french',
#  152: 'before',
#  153: 'general',
#  154: 'what',
#  155: 't',
#  156: 'against',
#  157: 'n',
#  158: 'high',
#  159: 'links',
#  160: 'could',
#  161: 'based',
#  162: 'those',
#  163: 'now',
#  164: 'second',
#  165: 'de',
#  166: 'music',
#  167: 'another',
#  168: 'large',
#  169: 'she',
#  170: 'f',
#  171: 'external',
#  172: 'german',
#  173: 'different',
#  174: 'modern',
#  175: 'great',
#  176: 'do',
#  177: 'common',
#  178: 'set',
#  179: 'list',
#  180: 'south',
#  181: 'series',
#  182: 'major',
#  183: 'game',
#  184: 'power',
#  185: 'long',
#  186: 'country',
#  187: 'king',
#  188: 'law',
#  189: 'group',
#  190: 'film',
#  191: 'still',
#  192: 'until',
#  193: 'north',
#  194: 'international',
#  195: 'term',
#  196: 'we',
#  197: 'end',
#  198: 'book',
#  199: 'found',
#  200: 'own',
#  201: 'political',
#  202: 'party',
#  203: 'order',
#  204: 'usually',
#  205: 'president',
#  206: 'church',
#  207: 'you',
#  208: 'death',
#  209: 'theory',
#  210: 'area',
#  211: 'around',
#  212: 'include',
#  213: 'god',
#  214: 'ii',
#  215: 'way',
#  216: 'did',
#  217: 'military',
#  218: 'population',
#  219: 'using',
#  220: 'though',
#  221: 'small',
#  222: 'following',
#  223: 'within',
#  224: 'non',
#  225: 'human',
#  226: 'left',
#  227: 'main',
#  228: 'among',
#  229: 'point',
#  230: 'r',
#  231: 'due',
#  232: 'p',
#  233: 'considered',
#  234: 'public',
#  235: 'popular',
#  236: 'computer',
#  237: 'west',
#  238: 'family',
#  239: 'east',
#  240: 'information',
#  241: 'important',
#  242: 'european',
#  243: 'man',
#  244: 'sometimes',
#  245: 'right',
#  246: 'old',
#  247: 'free',
#  248: 'word',
#  249: 'without',
#  250: 'last',
#  251: 'us',
#  252: 'members',
#  253: 'given',
#  254: 'times',
#  255: 'roman',
#  256: 'make',
#  257: 'h',
#  258: 'age',
#  259: 'place',
#  260: 'l',
#  261: 'thus',
#  262: 'science',
#  263: 'case',
#  264: 'become',
#  265: 'systems',
#  266: 'union',
#  267: 'born',
#  268: 'york',
#  269: 'line',
#  270: 'countries',
#  271: 'does',
#  272: 'isbn',
#  273: 'st',
#  274: 'control',
#  275: 'various',
#  276: 'others',
#  277: 'house',
#  278: 'article',
#  279: 'island',
#  280: 'should',
#  281: 'led',
#  282: 'back',
#  283: 'period',
#  284: 'player',
#  285: 'europe',
#  286: 'languages',
#  287: 'central',
#  288: 'water',
#  289: 'few',
#  290: 'western',
#  291: 'home',
#  292: 'began',
#  293: 'generally',
#  294: 'less',
#  295: 'k',
#  296: 'similar',
#  297: 'written',
#  298: 'original',
#  299: 'best',
#  300: 'must',
#  301: 'according',
#  302: 'school',
#  303: 'france',
#  304: 'air',
#  305: 'single',
#  306: 'force',
#  307: 'v',
#  308: 'land',
#  309: 'groups',
#  310: 'down',
#  311: 'how',
#  312: 'works',
#  313: 'development',
#  314: 'official',
#  315: 'support',
#  316: 'england',
#  317: 'j',
#  318: 'rather',
#  319: 'data',
#  320: 'space',
#  321: 'greek',
#  322: 'km',
#  323: 'named',
#  324: 'germany',
#  325: 'just',
#  326: 'games',
#  327: 'said',
#  328: 'version',
#  329: 'late',
#  330: 'earth',
#  331: 'company',
#  332: 'every',
#  333: 'economic',
#  334: 'short',
#  335: 'published',
#  336: 'black',
#  337: 'army',
#  338: 'off',
#  339: 'london',
#  340: 'million',
#  341: 'body',
#  342: 'field',
#  343: 'christian',
#  344: 'either',
#  345: 'social',
#  346: 'empire',
#  347: 'o',
#  348: 'developed',
#  349: 'standard',
#  350: 'court',
#  351: 'service',
#  352: 'kingdom',
#  353: 'along',
#  354: 'college',
#  355: 'republic',
#  356: 'sea',
#  357: 'america',
#  358: 'today',
#  359: 'result',
#  360: 'held',
#  361: 'team',
#  362: 'light',
#  363: 'means',
#  364: 'never',
#  365: 'especially',
#  366: 'third',
#  367: 'further',
#  368: 'character',
#  369: 'forces',
#  370: 'take',
#  371: 'men',
#  372: 'society',
#  373: 'show',
#  374: 'open',
#  375: 'possible',
#  376: 'fact',
#  377: 'battle',
#  378: 'took',
#  379: 'former',
#  380: 'books',
#  381: 'soviet',
#  382: 'river',
#  383: 'children',
#  384: 'having',
#  385: 'good',
#  386: 'local',
#  387: 'current',
#  388: 'son',
#  389: 'process',
#  390: 'natural',
#  391: 'present',
#  392: 'himself',
#  393: 'islands',
#  394: 'total',
#  395: 'near',
#  396: 'white',
#  397: 'days',
#  398: 'person',
#  399: 'itself',
#  400: 'seen',
#  401: 'culture',
#  402: 'little',
#  403: 'above',
#  404: 'software',
#  405: 'largest',
#  406: 'words',
#  407: 'upon',
#  408: 'level',
#  409: 'father',
#  410: 'created',
#  411: 'side',
#  412: 'red',
#  413: 'references',
#  414: 'press',
#  415: 'full',
#  416: 'region',
#  417: 'almost',
#  418: 'image',
#  419: 'al',
#  420: 'famous',
#  421: 'play',
#  422: 'came',
#  423: 'role',
#  424: 'once',
#  425: 'certain',
#  426: 'league',
#  427: 'jewish',
#  428: 'james',
#  429: 'january',
#  430: 'site',
#  431: 'again',
#  432: 'numbers',
#  433: 'art',
#  434: 'member',
#  435: 'areas',
#  436: 'movement',
#  437: 'religious',
#  438: 'type',
#  439: 'march',
#  440: 'community',
#  441: 'story',
#  442: 'played',
#  443: 'production',
#  444: 'released',
#  445: 'center',
#  446: 'rights',
#  447: 'real',
#  448: 'related',
#  449: 'foreign',
#  450: 'low',
#  451: 'ancient',
#  452: 'terms',
#  453: 'view',
#  454: 'source',
#  455: 'act',
#  456: 'minister',
#  457: 'change',
#  458: 'energy',
#  459: 'produced',
#  460: 'research',
#  461: 'actor',
#  462: 'making',
#  463: 'civil',
#  464: 'december',
#  465: 'women',
#  466: 'special',
#  467: 'style',
#  468: 'william',
#  469: 'design',
#  470: 'japanese',
#  471: 'available',
#  472: 'chinese',
#  473: 'forms',
#  474: 'canada',
#  475: 'northern',
#  476: 'died',
#  477: 'class',
#  478: 'living',
#  479: 'next',
#  480: 'particular',
#  481: 'program',
#  482: 'council',
#  483: 'television',
#  484: 'head',
#  485: 'david',
#  486: 'china',
#  487: 'middle',
#  488: 'established',
#  489: 'hand',
#  490: 'bc',
#  491: 'far',
#  492: 'july',
#  493: 'function',
#  494: 'position',
#  495: 'y',
#  496: 'built',
#  497: 'george',
#  498: 'band',
#  499: 'together',
#  500: 'w',
#  501: 'latin',
#  502: 'thought',
#  503: 'eastern',
#  504: 'charles',
#  505: 'parts',
#  506: 'instead',
#  507: 'study',
#  508: 'might',
#  509: 'india',
#  510: 'code',
#  511: 'included',
#  512: 'meaning',
#  513: 'trade',
#  514: 'per',
#  515: 'june',
#  516: 'least',
#  517: 'half',
#  518: 'model',
#  519: 'economy',
#  520: 'prime',
#  521: 'traditional',
#  522: 'always',
#  523: 'capital',
#  524: 'range',
#  525: 'november',
#  526: 'emperor',
#  527: 'young',
#  528: 'anti',
#  529: 'final',
#  530: 'text',
#  531: 'players',
#  532: 'uk',
#  533: 'april',
#  534: 'run',
#  535: 'september',
#  536: 'addition',
#  537: 'radio',
#  538: 'live',
#  539: 'august',
#  540: 'taken',
#  541: 'note',
#  542: 'italian',
#  543: 'lost',
#  544: 'nature',
#  545: 'project',
#  546: 'technology',
#  547: 'spanish',
#  548: 'october',
#  549: 'recent',
#  550: 'rate',
#  551: 'won',
#  552: 'true',
#  553: 'value',
#  554: 'uses',
#  555: 'russian',
#  556: 'est',
#  557: 'wrote',
#  558: 'effect',
#  559: 'album',
#  560: 'southern',
#  561: 'africa',
#  562: 'whose',
#  563: 'top',
#  564: 'historical',
#  565: 'australia',
#  566: 'catholic',
#  567: 'particularly',
#  568: 'self',
#  569: 'structure',
#  570: 'record',
#  571: 'evidence',
#  572: 'rule',
#  573: 'themselves',
#  574: 'influence',
#  575: 'cases',
#  576: 'subject',
#  577: 'referred',
#  578: 'continued',
#  579: 'nations',
#  580: 'below',
#  581: 'rock',
#  582: 'japan',
#  583: 'com',
#  584: 'song',
#  585: 'throughout',
#  586: 'names',
#  587: 'female',
#  588: 'title',
#  589: 'therefore',
#  590: 'our',
#  591: 'office',
#  592: 'star',
#  593: 'paul',
#  594: 'too',
#  595: 'cities',
#  596: 'february',
#  597: 'independent',
#  598: 'author',
#  599: 'problem',
#  600: 'species',
#  601: 'education',
#  602: 'done',
#  603: 'philosophy',
#  604: 'come',
#  605: 'higher',
#  606: 'originally',
#  607: 'market',
#  608: 'town',
#  609: 'my',
#  610: 'season',
#  611: 'love',
#  612: 'strong',
#  613: 'israel',
#  614: 'irish',
#  615: 'writer',
#  616: 'films',
#  617: 'elements',
#  618: 'robert',
#  619: 'whether',
#  620: 'despite',
#  621: 'eventually',
#  622: 'here',
#  623: 'football',
#  624: 'action',
#  625: 'internet',
#  626: 'individual',
#  627: 'sound',
#  628: 'network',
#  629: 'described',
#  630: 'practice',
#  631: 'characters',
#  632: 're',
#  633: 'royal',
#  634: 'la',
#  635: 'events',
#  636: 'formed',
#  637: 'commonly',
#  638: 'base',
#  639: 'received',
#  640: 'african',
#  641: 'problems',
#  642: 'food',
#  643: 'jews',
#  644: 'able',
#  645: 'male',
#  646: 'typically',
#  647: 'mass',
#  648: 'complex',
#  649: 'lower',
#  650: 'includes',
#  651: 'outside',
#  652: 'legal',
#  653: 'complete',
#  654: 'significant',
#  655: 'parliament',
#  656: 'actually',
#  657: 'business',
#  658: 'fiction',
#  659: 'physical',
#  660: 'followed',
#  661: 'deaths',
#  662: 'key',
#  663: 'leader',
#  664: 'widely',
#  665: 'page',
#  666: 'basic',
#  667: 'types',
#  668: 'henry',
#  669: 'elected',
#  670: 'beginning',
#  671: 'fire',
#  672: 'building',
#  673: 'independence',
#  674: 'went',
#  675: 'movie',
#  676: 'aircraft',
#  677: 'ever',
#  678: 'canadian',
#  679: 'material',
#  680: 'births',
#  681: 'video',
#  682: 'news',
#  683: 'future',
#  684: 'scientific',
#  685: 'simply',
#  686: 'go',
#  687: 'defined',
#  688: 'laws',
#  689: 'get',
#  690: 'close',
#  691: 'industry',
#  692: 'specific',
#  693: 'examples',
#  694: 'believe',
#  695: 'services',
#  696: 'idea',
#  697: 'method',
#  698: 'introduced',
#  699: 'points',
#  700: 'return',
#  701: 'cause',
#  702: 'indian',
#  703: 'britain',
#  704: 'features',
#  705: 'majority',
#  706: 'size',
#  707: 'post',
#  708: 'lead',
#  709: 'organization',
#  710: 'cannot',
#  711: 'designed',
#  712: 'ireland',
#  713: 'cross',
#  714: 'classical',
#  715: 'personal',
#  716: 'writing',
#  717: 'concept',
#  718: 'associated',
#  719: 'required',
#  720: 'soon',
#  721: 'changes',
#  722: 'california',
#  723: 'located',
#  724: 'sense',
#  725: 'believed',
#  726: 'away',
#  727: 'started',
#  728: 'co',
#  729: 'religion',
#  730: 'mother',
#  731: 'county',
#  732: 'rules',
#  733: 'studies',
#  734: 'yet',
#  735: 'find',
#  736: 'knowledge',
#  737: 'put',
#  738: 'founded',
#  739: 'policy',
#  740: 'currently',
#  741: 'provide',
#  742: 'working',
#  743: 'media',
#  744: 'election',
#  745: 'australian',
#  746: 'me',
#  747: 'thomas',
#  748: 'allowed',
#  749: 'russia',
#  750: 'earlier',
#  751: 'greater',
#  752: 'limited',
#  753: 'object',
#  754: 'brought',
#  755: 'online',
#  756: 'association',
#  757: 'lord',
#  758: 'mostly',
#  759: 'blue',
#  760: 'constitution',
#  761: 'across',
#  762: 'added',
#  763: 'interest',
#  764: 'things',
#  765: 'relations',
#  766: 'speed',
#  767: 'federal',
#  768: 'singer',
#  769: 'effects',
#  770: 'growth',
#  771: 'sources',
#  772: 'your',
#  773: 'remains',
#  774: 'z',
#  775: 'probably',
#  776: 'gave',
#  777: 'simple',
#  778: 'attack',
#  779: 'longer',
#  780: 'reference',
#  781: 'saint',
#  782: 'success',
#  783: 'killed',
#  784: 'past',
#  785: 'career',
#  786: 'need',
#  787: 'park',
#  788: 'definition',
#  789: 'say',
#  790: 'etc',
#  791: 'give',
#  792: 'peace',
#  793: 'chief',
#  794: 'stories',
#  795: 'security',
#  796: 'wide',
#  797: 'ball',
#  798: 'saw',
#  799: 'machine',
#  800: 'better',
#  801: 'cell',
#  802: 'leading',
#  803: 'becomes',
#  804: 'spain',
#  805: 'larger',
#  806: 'products',
#  807: 'parties',
#  808: 'night',
#  809: 'remained',
#  810: 'prize',
#  811: 'months',
#  812: 'website',
#  813: 'big',
#  814: 'cultural',
#  815: 'money',
#  816: 'help',
#  817: 'territory',
#  818: 'private',
#  819: 'moved',
#  820: 'letter',
#  821: 'wife',
#  822: 'politics',
#  823: 'lines',
#  824: 'largely',
#  825: 'contains',
#  826: 'companies',
#  827: 'lake',
#  828: 'perhaps',
#  829: 'green',
#  830: 'already',
#  831: 'dead',
#  832: 'iii',
#  833: 'library',
#  834: 'separate',
#  835: 'refer',
#  836: 'makes',
#  837: 'appeared',
#  838: 'dutch',
#  839: 'holy',
#  840: 'era',
#  841: 'novel',
#  842: 'successful',
#  843: 'italy',
#  844: 'letters',
#  845: 'results',
#  846: 'matter',
#  847: 'produce',
#  848: 'origin',
#  849: 'claim',
#  850: 'whole',
#  851: 'directly',
#  852: 'attempt',
#  853: 'actress',
#  854: 'surface',
#  855: 'revolution',
#  856: 'highly',
#  857: 'caused',
#  858: 'status',
#  859: 'musical',
#  860: 'richard',
#  861: 'commercial',
#  862: 'division',
#  863: 'color',
#  864: 'health',
#  865: 'coast',
#  866: 'release',
#  867: 'latter',
#  868: 'authority',
#  869: 'treaty',
#  870: 'turn',
#  871: 'michael',
#  872: 'nation',
#  873: 'direct',
#  874: 'asia',
#  875: 'edition',
#  876: 'programming',
#  877: 'playing',
#  878: 'date',
#  879: 'mary',
#  880: 'native',
#  881: 'whom',
#  882: 'married',
#  883: 'towards',
#  884: 'issues',
#  885: 'double',
#  886: 'primary',
#  887: 'basis',
#  888: 'allow',
#  889: 'enough',
#  890: 'memory',
#  891: 'reason',
#  892: 'web',
#  893: 'exist',
#  894: 'provided',
#  895: 'oil',
#  896: 'course',
#  897: 'functions',
#  898: 'alexander',
#  899: 'analysis',
#  900: 'chemical',
#  901: 'mid',
#  902: 'replaced',
#  903: 'queen',
#  904: 'claims',
#  905: 'tv',
#  906: 'sun',
#  907: 'literature',
#  908: 'metal',
#  909: 'amount',
#  910: 'divided',
#  911: 'blood',
#  912: 'likely',
#  913: 'access',
#  914: 'average',
#  915: 'length',
#  916: 'smaller',
#  917: 'medical',
#  918: 'property',
#  919: 'students',
#  920: 'degree',
#  921: 'elections',
#  922: 'club',
#  923: 'claimed',
#  924: 'performance',
#  925: 'director',
#  926: 'digital',
#  927: 'front',
#  928: 'museum',
#  929: 'difficult',
#  930: 'tradition',
#  931: 'nearly',
#  932: 'schools',
#  933: 'washington',
#  934: 'gas',
#  935: 'jesus',
#  936: 'map',
#  937: 'louis',
#  938: 'rome',
#  939: 'unit',
#  940: 'baseball',
#  941: 'mind',
#  942: 'peter',
#  943: 'mark',
#  944: 'collection',
#  945: 'product',
#  946: 'congress',
#  947: 'programs',
#  948: 'changed',
#  949: 'ideas',
#  950: 'moon',
#  951: 'entire',
#  952: 'user',
#  953: 'ground',
#  954: 'records',
#  955: 'frequently',
#  956: 'increase',
#  957: 'highest',
#  958: 'sent',
#  959: 'finally',
#  960: 'board',
#  961: 'don',
#  962: 'notable',
#  963: 'read',
#  964: 'methods',
#  965: 'recently',
#  966: 'bit',
#  967: 'involved',
#  968: 'variety',
#  969: 'call',
#  970: 'democratic',
#  971: 'ten',
#  972: 'served',
#  973: 'minor',
#  974: 'hard',
#  975: 'birth',
#  976: 'objects',
#  977: 'nuclear',
#  978: 'increased',
#  979: 'section',
#  980: 'street',
#  981: 'windows',
#  982: 'relatively',
#  983: 'car',
#  984: 'move',
#  985: 'create',
#  986: 'returned',
#  987: 'bank',
#  988: 'conditions',
#  989: 'operation',
#  990: 'adopted',
#  991: 'relationship',
#  992: 'christ',
#  993: 'hall',
#  994: 'appear',
#  995: 'rest',
#  996: 'child',
#  997: 'element',
#  998: 'appears',
#  999: 'takes',
#  ...}

# %%
np.ndarray(shape=(10,1),dtype=np.int32)
# Out:
# array([[ 889555688],
#        [       514],
#        [1583115840],
#        [         0],
#        [1583115968],
#        [         0],
#        [         0],
#        [         0],
#        [         0],
#        [         0]])

# %%
np.ndarray(shape=(10),dtype=np.int32)
# Out:
# array([ 886692752,        514, 1583115840,          0, 1583115968,
#                 0, 1583116096,          0, 1029034952,        514])

# %%
data_index=0

def generate_batch(batch_size,num_skips,skip_window):
    '''
    skip_window: 单词最远可联系的距离
    num_skips: 对每个单词生成样本数量，num_skips<=2*skip_window
    batch_size应是num_skips的整数倍
    span是某个单词创建相关样本时使用的单词个数，包括目标单词本身和其前后的单词，因此span=2*skip_window+1
    '''
    global data_index
    assert batch_size%num_skips==0
    assert num_skips<=2*skip_window
    batch=np.ndarray(shape=(batch_size),dtype=np.int32)
    labels=np.ndarray(shape=(batch_size,1),dtype=np.int32)
    span=2*skip_window+1
    buffer=collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index=(data_index+1)%len(data)
    for i in range(batch_size//num_skips):
        target=skip_window
        targets_to_avoid=[skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target=random.randint(0,span-1)
            targets_to_avoid.append(target)
            batch[i*num_skips+j]=buffer[skip_window]  # feature, 目标单词
            labels[i*num_skips+j,0]=buffer[target]  # label， 语境单词/目标单词上下文
        buffer.append(data[data_index])
        data_index=(data_index+1)%len(data)
        
    return batch,labels

# %%
batch,labels=generate_batch(batch_size=8,num_skips=2,skip_window=1)
for i in range(8):
    print(batch[i],reverse_dictionary[batch[i]],'->',labels[i,0],reverse_dictionary[labels[i,0]])
# Out:
# 59 used -> 46 first
# 59 used -> 156 against
# 156 against -> 128 early
# 156 against -> 59 used
# 128 early -> 742 working
# 128 early -> 156 against
# 742 working -> 477 class
# 742 working -> 128 early

# %%
batch_size=128
embedding_size=128
skip_window=1
num_skips=2

valid_size=16
valid_window=100
valid_examples=np.random.choice(valid_window,valid_size,replace=False)
num_sampled=64

# %%
np.random.choice(10,3,replace=False)
# Out:
# array([8, 0, 3])

# %%
graph=tf.Graph()
with graph.as_default():
    train_inputs=tf.placeholder(tf.int32,shape=[batch_size])
    train_labels=tf.placeholder(tf.int32,shape=[batch_size,1])
    valid_dataset=tf.constant(valid_examples,dtype=tf.int32)
    
    with tf.device('/cpu:0'):
        embeddings=tf.Variable(tf.random_uniform([vocabulary_size,embedding_size],-1.,1.))
        embed=tf.nn.embedding_lookup(embeddings,train_inputs)
        nce_weights=tf.Variable(tf.truncated_normal([vocabulary_size,embedding_size],stddev=1./math.sqrt(embedding_size)))
        nce_biases=tf.Variable(tf.zeros([vocabulary_size]))
        
    loss=tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                      biases=nce_biases,
                                      labels=train_labels,
                                      inputs=embed,
                                      num_sampled=num_sampled,
                                      num_classes=vocabulary_size))
    optimizer=tf.train.GradientDescentOptimizer(1.).minimize(loss)
    
    norm=tf.sqrt(tf.reduce_mean(tf.square(embeddings),axis=1,keep_dims=True))
    normalized_embeddings=embeddings/norm
    valid_embeddings=tf.nn.embedding_lookup(normalized_embeddings,valid_dataset)
    similarity=tf.matmul(valid_embeddings,normalized_embeddings,transpose_b=True)
    
    init=tf.global_variables_initializer()
    num_steps=10001
    
    with tf.Session(graph=graph) as sess:
        init.run()
        print('initialized...')
        
        average_loss=0
        for step in range(num_steps):
            batch_inputs,batch_labels=generate_batch(batch_size,num_skips,skip_window)
            feed_dict={train_inputs:batch_inputs,train_labels:batch_labels}
            
            _,loss_val=sess.run([optimizer,loss],feed_dict=feed_dict)
            average_loss+=loss_val
            
            if step%200==0:
                if step>0:
                    average_loss/=200
                print(f'Step {step}-average loss: {average_loss}')
                average_loss=0
            
            if step%1000==0:
                sim=similarity.eval()
                for i in range(valid_size):
                    valid_word=reverse_dictionary[valid_examples[i]]
                    top_k=8
                    nearest=(-sim[i,:]).argsort()[1:top_k+1]
                    log_str=f'Nearest to {valid_word}'
                    
                    for k in range(top_k):
                        close_word=reverse_dictionary[nearest[k]]
                        log_str=f'{log_str} {close_word},'
                    print(log_str)
                    
        final_embeddings=normalized_embeddings.eval()
# Out:
# initialized...
# Step 0-average loss: 247.48025512695312
# Nearest to is maison, montezuma, interlude, proceeding, preclear, motorized, pharmacies, bucaram,
# Nearest to some wary, attention, crystal, cisneros, weidman, ansi, sacramental, dares,
# Nearest to d tattoo, exonerated, compressibility, demo, gch, shutter, vacant, merwara,
# Nearest to when algeria, subgenus, disestablished, demolish, hastings, lner, caenorhabditis, autocrat,
# Nearest to in gs, desi, zhou, lexeme, scranton, archimedes, prost, bomber,
# Nearest to also made, santana, coolant, stimulating, serine, absorber, maximin, exponentiation,
# Nearest to four madonna, previously, indictment, composition, combating, russification, sahih, saucers,
# Nearest to more depreciation, aristocrats, anarchists, gift, stoneman, loan, imperatoribus, attached,
# Nearest to no demigod, timeout, robeson, jeet, customers, kul, judith, parsimony,
# Nearest to can freed, gfdl, barnet, nathanael, frankel, volk, smelter, frontiersman,
# Nearest to states idf, hole, fusing, chemist, environmentally, mediawiki, folketing, clover,
# Nearest to UNK fermentation, pizarro, lott, neberg, met, marat, wads, hieronymus,
# Nearest to seven amplifies, wheeling, iarc, workprint, jello, coptic, inevitable, hills,
# Nearest to there osorio, rothschild, dilation, hustler, celestines, ontogeny, monophysites, myron,
# Nearest to united gd, negation, dispersive, paley, pastor, kazakhstani, warranty, enigma,
# Nearest to and keanu, counseled, tisdall, sects, imposing, centre, behaved, roam,
# Step 200-average loss: 208.23381843566895
# Step 400-average loss: 159.21993152618407
# Step 600-average loss: 133.3477875518799
# Step 800-average loss: 120.10842777252198
# Step 1000-average loss: 104.93604093551636
# Nearest to is century, reducing, co, three, s, topics, i, works,
# Nearest to some attention, de, disorders, concerto, base, seeing, utc, follow,
# Nearest to d against, modern, story, without, common, non, about, shutter,
# Nearest to when algeria, best, america, place, had, signed, jpg, s,
# Nearest to in jpg, altruists, film, novels, have, issue, site, as,
# Nearest to also made, washington, prominent, just, what, upon, famous, council,
# Nearest to four nine, eight, jpg, six, paris, york, has, academy,
# Nearest to more anarchists, democratic, image, books, gift, religion, attached, five,
# Nearest to no that, until, major, zero, continued, such, march, used,
# Nearest to can freed, making, out, people, morality, ran, rand, fight,
# Nearest to states to, turned, used, day, seven, two, described, fully,
# Nearest to UNK better, met, b, net, dhabi, political, it, now,
# Nearest to seven two, jpg, for, anconia, since, story, states, abu,
# Nearest to there what, upon, time, first, ayn, signed, train, before,
# Nearest to united well, alphabet, signed, asperger, halley, after, inspired, mother,
# Nearest to and the, cooperation, dagny, controversy, of, see, did, jpg,
# Step 1200-average loss: 96.03273077011109
# Step 1400-average loss: 89.66747785568238
# Step 1600-average loss: 80.89079345703125
# Step 1800-average loss: 76.11784624099731
# Step 2000-average loss: 71.41767511844635
# Nearest to is reducing, vs, century, religions, topics, newspapers, pigs, southern,
# Nearest to some ansi, attention, geometric, vs, seeing, quite, de, UNK,
# Nearest to d against, modern, story, vs, leto, radar, without, northern,
# Nearest to when algeria, best, america, place, experimentation, had, beacon, vs,
# Nearest to in of, vs, monarchy, altruists, and, jpg, have, charges,
# Nearest to also made, vs, prominent, washington, morning, upon, what, mean,
# Nearest to four vs, previously, nine, alien, composition, eight, paris, transponder,
# Nearest to more anarchists, democratic, trotsky, gift, religion, vegas, books, awareness,
# Nearest to no until, zero, that, major, continued, transform, lieberman, march,
# Nearest to can freed, ran, making, out, morality, vs, do, anthropology,
# Nearest to states vs, turned, alps, used, lyre, day, directors, kings,
# Nearest to UNK net, vs, ethiopian, b, astrology, vote, richard, wesley,
# Nearest to seven jpg, cession, ads, two, influential, story, anconia, reduced,
# Nearest to there what, baltimore, upon, time, vs, samoa, ayn, signed,
# Nearest to united well, trotsky, spoken, halley, asperger, signed, alphabet, included,
# Nearest to and the, of, vs, languages, dagny, iso, blanking, leo,
# Step 2200-average loss: 67.48091238975525
# Step 2400-average loss: 63.2120467042923
# Step 2600-average loss: 59.293559093475345
# Step 2800-average loss: 52.32622704029083
# Step 3000-average loss: 53.79031595230103
# Nearest to is reducing, agave, proceeding, ada, vs, century, religions, pigs,
# Nearest to some attention, ansi, geometric, seeing, quite, hours, emissions, vs,
# Nearest to d weber, against, gland, modern, story, vs, northern, common,
# Nearest to when algeria, best, america, place, beacon, experimentation, had, vella,
# Nearest to in of, and, gland, agave, to, altruists, by, have,
# Nearest to also made, vs, prominent, size, morning, washington, famous, donald,
# Nearest to four vs, previously, composition, nine, alien, agave, eight, paris,
# Nearest to more anarchists, attached, democratic, gift, religion, astronauts, trotsky, ada,
# Nearest to no until, that, molecular, transform, major, continued, march, zero,
# Nearest to can freed, crew, making, ran, alphabetical, morality, p, do,
# Nearest to states turned, vs, alps, day, fully, lyre, agave, used,
# Nearest to UNK agave, blogs, research, born, fresh, resulting, am, vote,
# Nearest to seven anconia, jpg, ads, cession, influential, eggs, reduced, farming,
# Nearest to there what, molecules, baltimore, time, var, upon, alphabetic, vs,
# Nearest to united tar, spoken, usa, trotsky, well, alphabet, inspired, halley,
# Nearest to and of, in, the, languages, vs, gland, reginae, to,
# Step 3200-average loss: 51.88094110488892
# Step 3400-average loss: 46.45894223690033
# Step 3600-average loss: 48.35286903858185
# Step 3800-average loss: 44.76255473613739
# Step 4000-average loss: 40.15906862258911
# Nearest to is proceeding, reducing, agave, ada, religions, mistake, vs, century,
# Nearest to some ansi, attention, geometric, seeing, quite, hours, emissions, UNK,
# Nearest to d weber, gland, against, preston, modern, story, vs, covering,
# Nearest to when algeria, best, america, place, beacon, flourished, violent, experimentation,
# Nearest to in of, and, to, by, gland, film, agave, kangaroo,
# Nearest to also made, vs, allies, prominent, size, municipalities, morning, famous,
# Nearest to four composition, vs, previously, nine, agave, eight, paris, residents,
# Nearest to more attached, anarchists, depreciation, democratic, bottom, astronauts, gift, religion,
# Nearest to no robeson, until, that, molecular, major, transform, continued, zero,
# Nearest to can freed, crew, making, ran, alphabetical, morality, distinctive, st,
# Nearest to states turned, fully, alps, day, androids, del, lyre, hole,
# Nearest to UNK agave, blogs, difficult, leonard, b, large, vs, environment,
# Nearest to seven ads, anconia, jpg, december, reduced, two, influential, vs,
# Nearest to there what, baltimore, molecules, time, var, provided, train, alphabetic,
# Nearest to united tar, spoken, trotsky, inspired, halley, alphabet, usa, signed,
# Nearest to and of, in, to, the, vs, zero, gland, reginae,
# Step 4200-average loss: 37.68801418066025
# Step 4400-average loss: 40.02916949272156
# Step 4600-average loss: 34.837168817520144
# Step 4800-average loss: 34.607734961509706
# Step 5000-average loss: 34.18708490133285
# Nearest to is processors, ada, agave, proceeding, ball, retracted, religions, in,
# Nearest to some attention, geometric, ansi, seeing, quite, hours, emissions, utc,
# Nearest to d weber, gland, against, preston, modern, story, vs, hindi,
# Nearest to when algeria, rotate, america, best, place, violent, beacon, ari,
# Nearest to in of, and, processors, gland, to, by, on, film,
# Nearest to also made, vs, allies, prominent, morning, video, municipalities, size,
# Nearest to four composition, rotate, vs, previously, nine, dilation, paris, shells,
# Nearest to more attached, anarchists, depreciation, rotate, democratic, bottom, astronauts, gift,
# Nearest to no robeson, that, until, major, molecular, backfield, transform, continued,
# Nearest to can freed, making, ran, crew, alphabetical, nathanael, morality, fight,
# Nearest to states turned, alps, fully, hole, day, pallas, androids, vs,
# Nearest to UNK agave, gland, blogs, vs, fresh, difficult, vila, her,
# Nearest to seven anconia, influential, ads, two, competition, story, nautical, reduced,
# Nearest to there what, baltimore, molecules, time, var, train, upon, provided,
# Nearest to united spoken, tar, trotsky, inspired, halley, alphabet, usa, signed,
# Nearest to and in, of, gland, vs, reginae, the, zero, with,
# Step 5200-average loss: 32.93812355041504
# Step 5400-average loss: 31.89384117603302
# Step 5600-average loss: 31.969724855422974
# Step 5800-average loss: 29.610390934944153
# Step 6000-average loss: 27.717304821014405
# Nearest to is processors, was, in, s, agave, are, ada, andrei,
# Nearest to some attention, geometric, ansi, emissions, seeing, the, crystal, quite,
# Nearest to d gch, weber, gland, against, preston, modern, story, hindi,
# Nearest to when algeria, rotate, best, demolish, america, place, violent, flourished,
# Nearest to in and, of, by, to, cardinality, on, gland, at,
# Nearest to also made, vs, morning, allies, prominent, video, employer, donald,
# Nearest to four composition, rotate, previously, asterism, vs, zero, nine, agave,
# Nearest to more attached, anarchists, depreciation, rotate, astronauts, democratic, bottom, gift,
# Nearest to no robeson, that, until, customers, backfield, transform, molecular, continued,
# Nearest to can freed, making, ran, alphabetical, crew, nathanael, morality, fight,
# Nearest to states turned, directors, rotors, the, alps, fully, day, hole,
# Nearest to UNK agave, and, gland, vs, the, blogs, vilayet, white,
# Nearest to seven two, zero, ads, influential, anconia, story, competition, nautical,
# Nearest to there what, molecules, baltimore, time, train, var, provided, astronaut,
# Nearest to united negation, tar, spoken, trotsky, macintosh, inspired, alphabet, halley,
# Nearest to and in, of, UNK, gland, the, to, zero, vs,
# Step 6200-average loss: 26.67402592420578
# Step 6400-average loss: 25.985450162887574
# Step 6600-average loss: 25.00681792020798
# Step 6800-average loss: 24.602507503032683
# Step 7000-average loss: 22.302043097019194
# Nearest to is and, in, was, are, processors, s, agave, from,
# Nearest to some attention, geometric, ansi, crystal, emissions, seeing, hours, quite,
# Nearest to d gch, weber, gland, preston, against, modern, story, hindi,
# Nearest to when algeria, rotate, best, demolish, america, place, s, violent,
# Nearest to in of, and, by, to, on, cardinality, for, UNK,
# Nearest to also made, vs, morning, allies, prominent, video, soup, employer,
# Nearest to four composition, rotate, asterism, previously, vs, nine, agave, zero,
# Nearest to more attached, anarchists, depreciation, rotate, gift, bottom, astronauts, democratic,
# Nearest to no robeson, that, until, kiss, customers, backfield, continued, major,
# Nearest to can freed, making, ran, alphabetical, crew, morality, asterism, fight,
# Nearest to states turned, directors, the, rotors, day, fully, alps, pallas,
# Nearest to UNK and, agave, gland, vs, the, a, jpg, zero,
# Nearest to seven coke, two, ads, anconia, story, influential, zero, competition,
# Nearest to there what, baltimore, molecules, train, provided, time, var, signed,
# Nearest to united negation, spoken, tar, trotsky, inspired, macintosh, halley, alphabet,
# Nearest to and in, UNK, of, to, zero, the, gland, for,
# Step 7200-average loss: 23.131629631519317
# Step 7400-average loss: 23.52993111371994
# Step 7600-average loss: 21.696074974536895
# Step 7800-average loss: 19.657626581192016
# Step 8000-average loss: 21.54101356267929
# Nearest to is was, UNK, and, mathbf, in, are, psi, agave,
# Nearest to some mathbf, attention, geometric, crystal, ansi, emissions, seeing, quite,
# Nearest to d gch, weber, gland, preston, against, psi, hindi, modern,
# Nearest to when algeria, rotate, mathbf, best, demolish, flourished, violent, hastings,
# Nearest to in of, and, UNK, by, mathbf, on, to, at,
# Nearest to also made, allies, vs, morning, mathbf, soup, covalent, prominent,
# Nearest to four composition, rotate, nine, vs, asterism, UNK, mathbf, phi,
# Nearest to more attached, depreciation, anarchists, rotate, astronauts, democratic, gift, bottom,
# Nearest to no robeson, that, kiss, customers, until, aster, UNK, backfield,
# Nearest to can freed, alphabetical, ran, making, crew, phi, morality, psi,
# Nearest to states turned, the, UNK, directors, rotors, fully, day, pallas,
# Nearest to UNK mathbf, agave, phi, gland, and, vs, the, one,
# Nearest to seven two, mathbf, zero, coke, influential, anconia, ads, phi,
# Nearest to there what, baltimore, alum, molecules, train, provided, var, boer,
# Nearest to united negation, spoken, tar, macintosh, trotsky, inspired, halley, hall,
# Nearest to and UNK, of, in, phi, zero, mathbf, gland, to,
# Step 8200-average loss: 22.374280030727387
# Step 8400-average loss: 19.73702180147171
# Step 8600-average loss: 19.24506155014038
# Step 8800-average loss: 17.843408465385437
# Step 9000-average loss: 18.42388070344925
# Nearest to is was, are, in, and, mathbf, from, agave, had,
# Nearest to some mathbf, attention, geometric, crystal, ansi, emissions, seeing, quite,
# Nearest to d weber, gland, gch, preston, hindi, tattoo, against, story,
# Nearest to when algeria, rotate, best, mathbf, s, demolish, flourished, almond,
# Nearest to in and, of, on, mathbf, by, at, UNK, to,
# Nearest to also made, allies, employer, morning, mathbf, vs, covalent, soup,
# Nearest to four composition, nine, rotate, vs, phi, asterism, mathbf, agave,
# Nearest to more attached, depreciation, anarchists, gift, rotate, astronauts, democratic, bottom,
# Nearest to no robeson, that, customers, kiss, backfield, until, transform, continued,
# Nearest to can freed, alphabetical, ran, making, drag, crew, acad, phi,
# Nearest to states turned, directors, the, chemist, rotors, fully, hole, day,
# Nearest to UNK mathbf, agave, one, phi, gland, the, and, a,
# Nearest to seven mathbf, zero, nine, coke, two, phi, anconia, ads,
# Nearest to there what, baltimore, alum, molecules, train, provided, boer, var,
# Nearest to united negation, spoken, macintosh, tar, trotsky, halley, inspired, hall,
# Nearest to and of, in, UNK, phi, mathbf, the, gland, or,
# Step 9200-average loss: 16.73070869445801
# Step 9400-average loss: 15.60516783952713
# Step 9600-average loss: 16.14933658838272
# Step 9800-average loss: 16.910906310081483
# Step 10000-average loss: 15.824467570781708
# Nearest to is was, are, in, and, mathbf, had, from, with,
# Nearest to some mathbf, attention, geometric, crystal, ansi, emissions, seeing, hours,
# Nearest to d gland, weber, gch, preston, hindi, against, tattoo, modern,
# Nearest to when algeria, rotate, mathbf, s, best, hastings, flourished, demolish,
# Nearest to in and, of, on, by, at, for, mathbf, with,
# Nearest to also made, allies, employer, morning, soup, mathbf, covalent, video,
# Nearest to four composition, rotate, nine, vs, asterism, phi, mathbf, agave,
# Nearest to more attached, depreciation, anarchists, rotate, gift, astronauts, bottom, aside,
# Nearest to no robeson, that, zero, kiss, customers, backfield, transform, continued,
# Nearest to can freed, alphabetical, ran, making, drag, acad, crew, phi,
# Nearest to states the, turned, directors, day, chemist, fully, rotors, growing,
# Nearest to UNK one, mathbf, agave, and, the, phi, gland, in,
# Nearest to seven mathbf, zero, coke, phi, two, nine, anconia, ads,
# Nearest to there what, baltimore, alum, molecules, train, provided, boer, var,
# Nearest to united negation, macintosh, spoken, tar, trotsky, halley, hall, inspired,
# Nearest to and in, of, or, phi, UNK, one, mathbf, with,

# %%
def plot_with_labels(low_dim_embs,labels,filename='tsne.png'):
    assert low_dim_embs.shape[0]>=len(labels),'low_dim_embs should greater than len(labels)'
    plt.figure(figsize=(18,18))
    for i,label in enumerate(labels):
        x,y=low_dim_embs[i,:]
        plt.scatter(x,y)
        plt.annotate(label,
                    xy=(x,y),
                    xytext=(5,2),
                    textcoords='offset points',
                    ha='right',
                    va='bottom')
    plt.savefig(filename)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
tsne=TSNE(perplexity=30,n_components=2,init='pca',n_iter=5000)
plot_only=500
low_dim_embs=tsne.fit_transform(final_embeddings[:plot_only,:])
labels=[reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs,labels)
